# %%
import pandas as pd
import numpy as np
from pandas import json_normalize

def generate_recoms(idx):
    """
    fetches recommendations for given song (id)
    """
    idx = int(idx)
    # light.npy is pre-saved recommendations for all songs to optimize time
    sim = np.load("../data/light.npy")
    df = pd.read_csv("../data/song_meta.csv")
    recoms_list = sim[idx, :]
    recommendation = []
    # entered = df.iloc[int(idx), 1]
    # print("Recommendations for: ", entered)
    for i in range(0, 10):
        song_name = df.iloc[int(recoms_list[i]), 1]
        artist_name = df.iloc[int(recoms_list[i]), 2]
        spotify_id = df.iloc[int(recoms_list[i]), 3]
        preview = df.iloc[int(recoms_list[i]), 5]
        if preview == 'not_avail':
            preview = ""
        img = df.iloc[int(recoms_list[i]), 6]
        # print(song_name, " by ", artist_name)
        temp_dict = {
            "song_name": song_name,
            "artist_name": artist_name,
            "spotify_id": spotify_id,
            "image_url": img,
            "preview": preview
        }
        recommendation.append(temp_dict)
    return recommendation
recoms = generate_recoms(10)
json_normalize(recoms)
# Out:
#                                    song_name               artist_name  \
# 0                                   The Show                     Lenka
# 1                             Rastaman Chant  Bob Marley & The Wailers
# 2                                  Imma Tell                 Tech N9ne
# 3    Faster Horses (The Cowboy And The Poet)               Tom T. Hall
# 4                             Off The Ground            Anderson .Paak
# 5                           Te Voy a Olvidar           Banda El Recodo
# 6                                  That Good                Snoop Dogg
# 7             Jeeps, Lex Coups, Bimaz & Benz                 Lost Boyz
# 8                      Dell' amore non si sa            Andrea Bocelli
# 9  Arms Around You (feat. Maluma & Swae Lee)              XXXTENTACION
#
#                spotify_id                                          image_url  \
# 0  1mHoqHeQClLBp5UO3TbUac  https://i.scdn.co/image/ab67616d0000b273738288...
# 1  196bjfNXvEDkODWVjq2RRN  https://i.scdn.co/image/ab67616d0000b27329d53a...
# 2  46t7etd7A3T5K1BDsw9Fjc  https://i.scdn.co/image/ab67616d0000b27364422c...
# 3  11QUG7teTcHUXgP1KsdvuX  https://i.scdn.co/image/ab67616d0000b273629b2f...
# 4  2HsadrpAUp28eDIOhR2hPC  https://i.scdn.co/image/ab67616d0000b2731904cf...
# 5  0i2ivIlhyo2pJsHVKJCWlb  https://i.scdn.co/image/ab67616d0000b273e555fc...
# 6  2OmfRyHIFAkMEEwmbgz7lN  https://i.scdn.co/image/ab67616d0000b273c303b2...
# 7  02nH7HXbs3i9kdWef9or8E  https://i.scdn.co/image/ab67616d0000b2730e8ff2...
# 8  0HBuMYQSIX4DF7mmcc3nUK  https://i.scdn.co/image/ab67616d0000b273d0166a...
# 9  2LskIZrCeLxRvCiGP8gxlh  https://i.scdn.co/image/ab67616d0000b27397edb4...
#
#                                              preview
# 0  https://p.scdn.co/mp3-preview/ef5d4650b52f81da...
# 1  https://p.scdn.co/mp3-preview/37e92ed302d25830...
# 2  https://p.scdn.co/mp3-preview/85a1e38a8e8c7ca6...
# 3  https://p.scdn.co/mp3-preview/f33fd88dc7ddb4e7...
# 4  https://p.scdn.co/mp3-preview/4f7d87a65f025a6f...
# 5  https://p.scdn.co/mp3-preview/d7706bc8a1122df5...
# 6
# 7
# 8  https://p.scdn.co/mp3-preview/577f3c42bf01f24f...
# 9
